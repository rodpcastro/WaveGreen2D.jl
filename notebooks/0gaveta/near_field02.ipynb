# %%
using JLD2
using StaticArrays
using WaveGreen2D.Chebyshev: ChebyshevSeries, TransformedChebyshevSeries, gradient, hessian, contains

# %%
cs = jldopen("../src/chebyshev_series.jld2")

const L₁_series = read(cs, "L₁_series")
const L₂_series = read(cs, "L₂_series")

close(cs);

# %%
function get_L₁_series_index(x::SVector{3, Float64})
    u = SVector{3, Float64}(x[1], x[2], log(x[3]))
    
    if contains(L₁_series[1], x)
        return 1
    elseif contains(L₁_series[2], u)
        return 2
    elseif contains(L₁_series[3], u)
        return 3
    else
        throw(DomainError(x, "Point not in the domain of L₁ Chebyshev series."))
    end
end


function get_L₂_series_index(x::SVector{3, Float64})
    u = SVector{3, Float64}(x[1], x[2], log(x[3]))
    
    if contains(L₂_series[1], u)
        return 1
    elseif contains(L₂_series[2], u)
        return 2
    elseif contains(L₂_series[3], u)
        return 3
    elseif contains(L₂_series[4], u)
        return 4
    else
        throw(DomainError(x, "Point not in the domain of L₂ Chebyshev series."))
    end
end


function L₁(A::Float64, B₁::Float64, H::Float64)
    x = SVector{3, Float64}(A, B₁, H)
    u = SVector{3, Float64}(A, B₁, log(H))
    i = get_L₁_series_index(x)

    if i == 1
        return L₁_series[i](x)
    end
    
    return L₁_series[i](u)
end


function ∇L₁(A::Float64, B₁::Float64, H::Float64)
    x = SVector{3, Float64}(A, B₁, H)
    u = SVector{3, Float64}(A, B₁, log(H))
    i = get_L₁_series_index(x)

    if i == 1
        return gradient(L₁_series[i], x)
    end
    
    L, ∇ᵤL = gradient(L₁_series[i], u)
    
    # ∂L/∂x = ∂L/∂u ⋅ ∂u/∂x
    ∇L = SVector{3, Float64}(∇ᵤL[1], ∇ᵤL[2], ∇ᵤL[3]/H)
    
    return L, ∇L
end


function HL₁(A::Float64, B₁::Float64, H::Float64)
    x = SVector{3, Float64}(A, B₁, H)
    u = SVector{3, Float64}(A, B₁, log(H))
    i = get_L₁_series_index(x)

    if i == 1
        return hessian(L₁_series[i], x)
    end
        
    L, ∇ᵤL, HᵤL = hessian(L₁_series[i], u)
    
    # ∂L/∂x = ∂L/∂u ⋅ ∂u/∂x
    ∇L = SVector{3, Float64}(∇ᵤL[1], ∇ᵤL[2], ∇ᵤL[3]/H)

    # ∂²L/∂x² = ∂L/∂u ⋅ ∂²u/∂x² + ∂²L/∂u² ⋅ (∂u/∂x)²
    HL¹ = zero(MMatrix{3, 3, Float64, 9})
    HL¹[3, 3] = -∇ᵤL[3] / H^2

    HL² = MMatrix{3, 3, Float64, 9}(HᵤL)
    HL²[3, :] .*= 1/H
    HL²[:, 3] .*= 1/H
    
    HL = SMatrix{3, 3, Float64, 9}(HL¹ + HL²)

    return L, ∇L, HL
end


function L₂(A::Float64, B₂::Float64, H::Float64)
    x = SVector{3, Float64}(A, B₂, H)
    u = SVector{3, Float64}(A, B₂, log(H))
    i = get_L₂_series_index(x)
    return L₂_series[i](u)
end


function ∇L₂(A::Float64, B₂::Float64, H::Float64)
    x = SVector{3, Float64}(A, B₂, H)
    u = SVector{3, Float64}(A, B₂, log(H))
    i = get_L₂_series_index(x)
    L, ∇ᵤL = gradient(L₂_series[i], u)
    
    # ∂L/∂x = ∂L/∂u ⋅ ∂u/∂x
    ∇L = SVector{3, Float64}(∇ᵤL[1], ∇ᵤL[2], ∇ᵤL[3]/H)
    
    return L, ∇L
end


function HL₂(A::Float64, B₂::Float64, H::Float64)
    x = SVector{3, Float64}(A, B₂, H)
    u = SVector{3, Float64}(A, B₂, log(H))
    i = get_L₂_series_index(x)
    L, ∇ᵤL, HᵤL = hessian(L₂_series[i], u)
    
    # ∂L/∂x = ∂L/∂u ⋅ ∂u/∂x
    ∇L = SVector{3, Float64}(∇ᵤL[1], ∇ᵤL[2], ∇ᵤL[3]/H)

    # ∂²L/∂x² = ∂L/∂u ⋅ ∂²u/∂x² + ∂²L/∂u² ⋅ (∂u/∂x)²
    HL¹ = zero(MMatrix{3, 3, Float64, 9})
    HL¹[3, 3] = -∇ᵤL[3] / H^2

    HL² = MMatrix{3, 3, Float64, 9}(HᵤL)
    HL²[3, :] .*= 1/H
    HL²[:, 3] .*= 1/H
    
    HL = SMatrix{3, 3, Float64, 9}(HL¹ + HL²)

    return L, ∇L, HL
end;

# %% [markdown]
# $L_1$
#
# -1.00169204874032
#
# [-0.06799288769514582, 0.28012825734268715, 0.15870001060024233]
#
# [-0.6732390207590058 -0.07372986793058411 0.08936761425251266; -0.07372986793058411 0.6732390207590058 -0.5061078894933684; 0.08936761425251266 -0.5061078894933684 0.11516526881129213]

# %%
L₁(0.1, 0.5, 0.3)
# Out:
# -1.0016920487403178

# %%
L, ∇L = ∇L₁(0.1, 0.5, 0.3)
println(L)
println(∇L)
# Out:
# -1.0016920487403178
# [-0.0679928876951603, 0.2801282573427111, 0.15870001060026287]

# %%
L, ∇L, HL = HL₁(0.1, 0.5, 0.3)
println(L)
println(∇L)
println(HL)
# Out:
# -1.0016920487403178
# [-0.0679928876951603, 0.2801282573427111, 0.15870001060026287]
# [-0.6732390207596641 -0.07372986793040157 0.08936761425249547; -0.07372986793040157 0.6732390207586858 -0.5061078894934178; 0.08936761425249547 -0.5061078894934178 0.11516526881072357]

# %% [markdown]
# $L_2$
#
# -1.039841625349199
#
# [0.012907603643945642, -0.2727287078066397, 6.283285000126575]
#
# [0.13029525572290562 0.022550617007363834 0.1454782528537148; 0.022550617007363834 -0.13029525572290554 1.700800437397748; 0.1454782528537148 1.700800437397748 -31.315956117865]

# %%
L₂(0.1, 0.5, 0.3)
# Out:
# -1.0398416253491993

# %%
L, ∇L = ∇L₂(0.1, 0.5, 0.3)
println(L)
println(∇L)
# Out:
# -1.0398416253491993
# [0.012907603643942457, -0.2727287078066322, 6.283285000126647]

# %%
L, ∇L, HL = HL₂(0.1, 0.5, 0.3)
println(L)
println(∇L)
println(HL)
# Out:
# -1.0398416253491993
# [0.012907603643942457, -0.2727287078066322, 6.283285000126647]
# [0.13029525572269504 0.022550617007205224 0.14547825285380964; 0.022550617007205224 -0.13029525572291006 1.7008004373977508; 0.14547825285380964 1.7008004373977508 -31.315956117865092]

# %%
@code_warntype L₁(0.1, 0.5, 0.3)
# Out:
# MethodInstance for L₁(::Float64, ::Float64, ::Float64)
#   from L₁(A::Float64, B₁::Float64, H::Float64) @ Main In[3]:33
# Arguments
#   #self#::Core.Const(Main.L₁)
#   A::Float64
#   B₁::Float64
#   H::Float64
# Locals
#   i::Int64
#   u::SVector{3, Float64}
#   x::SVector{3, Float64}
# Body::Float64
# 1 ─ %1  = Main.SVector::Core.Const(SVector)
# │   %2  = Main.Float64::Core.Const(Float64)
# │   %3  = Core.apply_type(%1, 3, %2)::Core.Const(SVector{3, Float64})
# │         (x = (%3)(A, B₁, H))
# │   %5  = Main.SVector::Core.Const(SVector)
# │   %6  = Main.Float64::Core.Const(Float64)
# │   %7  = Core.apply_type(%5, 3, %6)::Core.Const(SVector{3, Float64})
# │   %8  = Main.log::Core.Const(log)
# │   %9  = (%8)(H)::Float64
# │         (u = (%7)(A, B₁, %9))
# │   %11 = Main.get_L₁_series_index::Core.Const(Main.get_L₁_series_index)
# │   %12 = x::SVector{3, Float64}
# │         (i = (%11)(%12))
# │   %14 = Main.:(==)::Core.Const(==)
# │   %15 = i::Int64
# │   %16 = (%14)(%15, 1)::Bool
# └──       goto #3 if not %16
# 2 ─ %18 = Main.L₁_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 20)])
# │   %19 = i::Int64
# │   %20 = Base.getindex(%18, %19)::ChebyshevSeries{Float64, 3}
# │   %21 = x::SVector{3, Float64}
# │   %22 = (%20)(%21)::Float64
# └──       return %22
# 3 ─ %24 = Main.L₁_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 20)])
# │   %25 = i::Int64
# │   %26 = Base.getindex(%24, %25)::ChebyshevSeries{Float64, 3}
# │   %27 = u::SVector{3, Float64}
# │   %28 = (%26)(%27)::Float64
# └──       return %28

# %%
@code_warntype ∇L₁(0.1, 0.5, 0.3)
# Out:
# MethodInstance for ∇L₁(::Float64, ::Float64, ::Float64)
#   from ∇L₁(A::Float64, B₁::Float64, H::Float64) @ Main In[3]:46
# Arguments
#   #self#::Core.Const(Main.∇L₁)
#   A::Float64
#   B₁::Float64
#   H::Float64
# Locals
#   @_5::Int64
#   ∇L::SVector{3, Float64}
#   ∇ᵤL::SVector{3, Float64}
#   L::Float64
#   i::Int64
#   u::SVector{3, Float64}
#   x::SVector{3, Float64}
# Body::Tuple{Float64, SVector{3, Float64}}
# 1 ─       Core.NewvarNode(:(@_5))
# │         Core.NewvarNode(:(∇L))
# │         Core.NewvarNode(:(∇ᵤL))
# │         Core.NewvarNode(:(L))
# │   %5  = Main.SVector::Core.Const(SVector)
# │   %6  = Main.Float64::Core.Const(Float64)
# │   %7  = Core.apply_type(%5, 3, %6)::Core.Const(SVector{3, Float64})
# │         (x = (%7)(A, B₁, H))
# │   %9  = Main.SVector::Core.Const(SVector)
# │   %10 = Main.Float64::Core.Const(Float64)
# │   %11 = Core.apply_type(%9, 3, %10)::Core.Const(SVector{3, Float64})
# │   %12 = Main.log::Core.Const(log)
# │   %13 = (%12)(H)::Float64
# │         (u = (%11)(A, B₁, %13))
# │   %15 = Main.get_L₁_series_index::Core.Const(Main.get_L₁_series_index)
# │   %16 = x::SVector{3, Float64}
# │         (i = (%15)(%16))
# │   %18 = Main.:(==)::Core.Const(==)
# │   %19 = i::Int64
# │   %20 = (%18)(%19, 1)::Bool
# └──       goto #3 if not %20
# 2 ─ %22 = Main.gradient::Core.Const(WaveGreen2D.Chebyshev.gradient)
# │   %23 = Main.L₁_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 20)])
# │   %24 = i::Int64
# │   %25 = Base.getindex(%23, %24)::ChebyshevSeries{Float64, 3}
# │   %26 = x::SVector{3, Float64}
# │   %27 = (%22)(%25, %26)::Tuple{Float64, SVector{3, Float64}}
# └──       return %27
# 3 ─ %29 = Main.gradient::Core.Const(WaveGreen2D.Chebyshev.gradient)
# │   %30 = Main.L₁_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 20)])
# │   %31 = i::Int64
# │   %32 = Base.getindex(%30, %31)::ChebyshevSeries{Float64, 3}
# │   %33 = u::SVector{3, Float64}
# │   %34 = (%29)(%32, %33)::Tuple{Float64, SVector{3, Float64}}
# │   %35 = Base.indexed_iterate(%34, 1)::Core.PartialStruct(Tuple{Float64, Int64}, Any[Float64, Core.Const(2)])
# │         (L = Core.getfield(%35, 1))
# │         (@_5 = Core.getfield(%35, 2))
# │   %38 = @_5::Core.Const(2)
# │   %39 = Base.indexed_iterate(%34, 2, %38)::Core.PartialStruct(Tuple{SVector{3, Float64}, Int64}, Any[SVector{3, Float64}, Core.Const(3)])
# │         (∇ᵤL = Core.getfield(%39, 1))
# │   %41 = Main.SVector::Core.Const(SVector)
# │   %42 = Main.Float64::Core.Const(Float64)
# │   %43 = Core.apply_type(%41, 3, %42)::Core.Const(SVector{3, Float64})
# │   %44 = ∇ᵤL::SVector{3, Float64}
# │   %45 = Base.getindex(%44, 1)::Float64
# │   %46 = ∇ᵤL::SVector{3, Float64}
# │   %47 = Base.getindex(%46, 2)::Float64
# │   %48 = Main.:/::Core.Const(/)
# │   %49 = ∇ᵤL::SVector{3, Float64}
# │   %50 = Base.getindex(%49, 3)::Float64
# │   %51 = (%48)(%50, H)::Float64
# │         (∇L = (%43)(%45, %47, %51))
# │   %53 = L::Float64
# │   %54 = ∇L::SVector{3, Float64}
# │   %55 = Core.tuple(%53, %54)::Tuple{Float64, SVector{3, Float64}}
# └──       return %55

# %%
@code_warntype HL₁(0.1, 0.5, 0.3)
# Out:
# MethodInstance for HL₁(::Float64, ::Float64, ::Float64)
#   from HL₁(A::Float64, B₁::Float64, H::Float64) @ Main In[3]:64
# Arguments
#   #self#::Core.Const(Main.HL₁)
#   A::Float64
#   B₁::Float64
#   H::Float64
# Locals
#   @_5::Int64
#   HL::SMatrix{3, 3, Float64, 9}
#   HL²::MMatrix{3, 3, Float64, 9}
#   HL¹::MMatrix{3, 3, Float64, 9}
#   ∇L::SVector{3, Float64}
#   HᵤL::SMatrix{3, 3, Float64, 9}
#   ∇ᵤL::SVector{3, Float64}
#   L::Float64
#   i::Int64
#   u::SVector{3, Float64}
#   x::SVector{3, Float64}
# Body::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# 1 ─        Core.NewvarNode(:(@_5))
# │          Core.NewvarNode(:(HL))
# │          Core.NewvarNode(:(HL²))
# │          Core.NewvarNode(:(HL¹))
# │          Core.NewvarNode(:(∇L))
# │          Core.NewvarNode(:(HᵤL))
# │          Core.NewvarNode(:(∇ᵤL))
# │          Core.NewvarNode(:(L))
# │   %9   = Main.SVector::Core.Const(SVector)
# │   %10  = Main.Float64::Core.Const(Float64)
# │   %11  = Core.apply_type(%9, 3, %10)::Core.Const(SVector{3, Float64})
# │          (x = (%11)(A, B₁, H))
# │   %13  = Main.SVector::Core.Const(SVector)
# │   %14  = Main.Float64::Core.Const(Float64)
# │   %15  = Core.apply_type(%13, 3, %14)::Core.Const(SVector{3, Float64})
# │   %16  = Main.log::Core.Const(log)
# │   %17  = (%16)(H)::Float64
# │          (u = (%15)(A, B₁, %17))
# │   %19  = Main.get_L₁_series_index::Core.Const(Main.get_L₁_series_index)
# │   %20  = x::SVector{3, Float64}
# │          (i = (%19)(%20))
# │   %22  = Main.:(==)::Core.Const(==)
# │   %23  = i::Int64
# │   %24  = (%22)(%23, 1)::Bool
# └──        goto #3 if not %24
# 2 ─ %26  = Main.hessian::Core.Const(WaveGreen2D.Chebyshev.hessian)
# │   %27  = Main.L₁_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 20)])
# │   %28  = i::Int64
# │   %29  = Base.getindex(%27, %28)::ChebyshevSeries{Float64, 3}
# │   %30  = x::SVector{3, Float64}
# │   %31  = (%26)(%29, %30)::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# └──        return %31
# 3 ─ %33  = Main.hessian::Core.Const(WaveGreen2D.Chebyshev.hessian)
# │   %34  = Main.L₁_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 19), 3-D Chebyshev series of order (14, 19, 20)])
# │   %35  = i::Int64
# │   %36  = Base.getindex(%34, %35)::ChebyshevSeries{Float64, 3}
# │   %37  = u::SVector{3, Float64}
# │   %38  = (%33)(%36, %37)::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# │   %39  = Base.indexed_iterate(%38, 1)::Core.PartialStruct(Tuple{Float64, Int64}, Any[Float64, Core.Const(2)])
# │          (L = Core.getfield(%39, 1))
# │          (@_5 = Core.getfield(%39, 2))
# │   %42  = @_5::Core.Const(2)
# │   %43  = Base.indexed_iterate(%38, 2, %42)::Core.PartialStruct(Tuple{SVector{3, Float64}, Int64}, Any[SVector{3, Float64}, Core.Const(3)])
# │          (∇ᵤL = Core.getfield(%43, 1))
# │          (@_5 = Core.getfield(%43, 2))
# │   %46  = @_5::Core.Const(3)
# │   %47  = Base.indexed_iterate(%38, 3, %46)::Core.PartialStruct(Tuple{SMatrix{3, 3, Float64, 9}, Int64}, Any[SMatrix{3, 3, Float64, 9}, Core.Const(4)])
# │          (HᵤL = Core.getfield(%47, 1))
# │   %49  = Main.SVector::Core.Const(SVector)
# │   %50  = Main.Float64::Core.Const(Float64)
# │   %51  = Core.apply_type(%49, 3, %50)::Core.Const(SVector{3, Float64})
# │   %52  = ∇ᵤL::SVector{3, Float64}
# │   %53  = Base.getindex(%52, 1)::Float64
# │   %54  = ∇ᵤL::SVector{3, Float64}
# │   %55  = Base.getindex(%54, 2)::Float64
# │   %56  = Main.:/::Core.Const(/)
# │   %57  = ∇ᵤL::SVector{3, Float64}
# │   %58  = Base.getindex(%57, 3)::Float64
# │   %59  = (%56)(%58, H)::Float64
# │          (∇L = (%51)(%53, %55, %59))
# │   %61  = Main.zero::Core.Const(zero)
# │   %62  = Main.MMatrix::Core.Const(MMatrix)
# │   %63  = Main.Float64::Core.Const(Float64)
# │   %64  = Core.apply_type(%62, 3, 3, %63, 9)::Core.Const(MMatrix{3, 3, Float64, 9})
# │          (HL¹ = (%61)(%64))
# │   %66  = Main.:/::Core.Const(/)
# │   %67  = Main.:-::Core.Const(-)
# │   %68  = ∇ᵤL::SVector{3, Float64}
# │   %69  = Base.getindex(%68, 3)::Float64
# │   %70  = (%67)(%69)::Float64
# │   %71  = Main.:^::Core.Const(^)
# │   %72  = Core.apply_type(Base.Val, 2)::Core.Const(Val{2})
# │   %73  = (%72)()::Core.Const(Val{2}())
# │   %74  = Base.literal_pow(%71, H, %73)::Float64
# │   %75  = (%66)(%70, %74)::Float64
# │   %76  = HL¹::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │          Base.setindex!(%76, %75, 3, 3)
# │   %78  = Main.MMatrix::Core.Const(MMatrix)
# │   %79  = Main.Float64::Core.Const(Float64)
# │   %80  = Core.apply_type(%78, 3, 3, %79, 9)::Core.Const(MMatrix{3, 3, Float64, 9})
# │   %81  = HᵤL::SMatrix{3, 3, Float64, 9}
# │          (HL² = (%80)(%81))
# │   %83  = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %84  = Main.:(:)::Core.Const(Colon())
# │   %85  = Base.dotview(%83, 3, %84)::Core.PartialStruct(SizedVector{3, Float64, SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Int64, Base.Slice{SOneTo{3}}}, true}}, Any[Core.PartialStruct(SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Int64, Base.Slice{SOneTo{3}}}, true}, Any[Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}]), Core.Const((3, Base.Slice(SOneTo(3)))), Core.Const(0), Core.Const(3)])])
# │   %86  = Main.:*::Core.Const(*)
# │   %87  = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %88  = Main.:(:)::Core.Const(Colon())
# │   %89  = Base.getindex(%87, 3, %88)::Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}])
# │   %90  = Main.:/::Core.Const(/)
# │   %91  = (%90)(1, H)::Float64
# │   %92  = Base.broadcasted(%86, %89, %91)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{MVector{3, Float64}, Float64}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(*), Core.PartialStruct(Tuple{MVector{3, Float64}, Float64}, Any[Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}]), Float64]), Core.Const(nothing)])
# │          Base.materialize!(%85, %92)
# │   %94  = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %95  = Main.:(:)::Core.Const(Colon())
# │   %96  = Base.dotview(%94, %95, 3)::Core.PartialStruct(SizedVector{3, Float64, SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Base.Slice{SOneTo{3}}, Int64}, true}}, Any[Core.PartialStruct(SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Base.Slice{SOneTo{3}}, Int64}, true}, Any[Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}]), Core.Const((Base.Slice(SOneTo(3)), 3)), Core.Const(6), Core.Const(1)])])
# │   %97  = Main.:*::Core.Const(*)
# │   %98  = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %99  = Main.:(:)::Core.Const(Colon())
# │   %100 = Base.getindex(%98, %99, 3)::Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}])
# │   %101 = Main.:/::Core.Const(/)
# │   %102 = (%101)(1, H)::Float64
# │   %103 = Base.broadcasted(%97, %100, %102)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{MVector{3, Float64}, Float64}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(*), Core.PartialStruct(Tuple{MVector{3, Float64}, Float64}, Any[Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}]), Float64]), Core.Const(nothing)])
# │          Base.materialize!(%96, %103)
# │   %105 = Main.SMatrix::Core.Const(SMatrix)
# │   %106 = Main.Float64::Core.Const(Float64)
# │   %107 = Core.apply_type(%105, 3, 3, %106, 9)::Core.Const(SMatrix{3, 3, Float64, 9})
# │   %108 = Main.:+::Core.Const(+)
# │   %109 = HL¹::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %110 = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %111 = (%108)(%109, %110)::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │          (HL = (%107)(%111))
# │   %113 = L::Float64
# │   %114 = ∇L::SVector{3, Float64}
# │   %115 = HL::SMatrix{3, 3, Float64, 9}
# │   %116 = Core.tuple(%113, %114, %115)::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# └──        return %116

# %%
@code_warntype L₂(0.1, 0.5, 0.3)
# Out:
# MethodInstance for L₂(::Float64, ::Float64, ::Float64)
#   from L₂(A::Float64, B₂::Float64, H::Float64) @ Main In[3]:92
# Arguments
#   #self#::Core.Const(Main.L₂)
#   A::Float64
#   B₂::Float64
#   H::Float64
# Locals
#   i::Int64
#   u::SVector{3, Float64}
#   x::SVector{3, Float64}
# Body::Float64
# 1 ─ %1  = Main.SVector::Core.Const(SVector)
# │   %2  = Main.Float64::Core.Const(Float64)
# │   %3  = Core.apply_type(%1, 3, %2)::Core.Const(SVector{3, Float64})
# │         (x = (%3)(A, B₂, H))
# │   %5  = Main.SVector::Core.Const(SVector)
# │   %6  = Main.Float64::Core.Const(Float64)
# │   %7  = Core.apply_type(%5, 3, %6)::Core.Const(SVector{3, Float64})
# │   %8  = Main.log::Core.Const(log)
# │   %9  = (%8)(H)::Float64
# │         (u = (%7)(A, B₂, %9))
# │   %11 = Main.get_L₂_series_index::Core.Const(Main.get_L₂_series_index)
# │   %12 = x::SVector{3, Float64}
# │         (i = (%11)(%12))
# │   %14 = Main.L₂_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (11, 18, 23), 3-D Chebyshev series of order (11, 18, 22), 3-D Chebyshev series of order (12, 20, 21), 3-D Chebyshev series of order (13, 21, 21)])
# │   %15 = i::Int64
# │   %16 = Base.getindex(%14, %15)::ChebyshevSeries{Float64, 3}
# │   %17 = u::SVector{3, Float64}
# │   %18 = (%16)(%17)::Float64
# └──       return %18

# %%
@code_warntype ∇L₂(0.1, 0.5, 0.3)
# Out:
# MethodInstance for ∇L₂(::Float64, ::Float64, ::Float64)
#   from ∇L₂(A::Float64, B₂::Float64, H::Float64) @ Main In[3]:100
# Arguments
#   #self#::Core.Const(Main.∇L₂)
#   A::Float64
#   B₂::Float64
#   H::Float64
# Locals
#   @_5::Int64
#   ∇L::SVector{3, Float64}
#   ∇ᵤL::SVector{3, Float64}
#   L::Float64
#   i::Int64
#   u::SVector{3, Float64}
#   x::SVector{3, Float64}
# Body::Tuple{Float64, SVector{3, Float64}}
# 1 ─ %1  = Main.SVector::Core.Const(SVector)
# │   %2  = Main.Float64::Core.Const(Float64)
# │   %3  = Core.apply_type(%1, 3, %2)::Core.Const(SVector{3, Float64})
# │         (x = (%3)(A, B₂, H))
# │   %5  = Main.SVector::Core.Const(SVector)
# │   %6  = Main.Float64::Core.Const(Float64)
# │   %7  = Core.apply_type(%5, 3, %6)::Core.Const(SVector{3, Float64})
# │   %8  = Main.log::Core.Const(log)
# │   %9  = (%8)(H)::Float64
# │         (u = (%7)(A, B₂, %9))
# │   %11 = Main.get_L₂_series_index::Core.Const(Main.get_L₂_series_index)
# │   %12 = x::SVector{3, Float64}
# │         (i = (%11)(%12))
# │   %14 = Main.gradient::Core.Const(WaveGreen2D.Chebyshev.gradient)
# │   %15 = Main.L₂_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (11, 18, 23), 3-D Chebyshev series of order (11, 18, 22), 3-D Chebyshev series of order (12, 20, 21), 3-D Chebyshev series of order (13, 21, 21)])
# │   %16 = i::Int64
# │   %17 = Base.getindex(%15, %16)::ChebyshevSeries{Float64, 3}
# │   %18 = u::SVector{3, Float64}
# │   %19 = (%14)(%17, %18)::Tuple{Float64, SVector{3, Float64}}
# │   %20 = Base.indexed_iterate(%19, 1)::Core.PartialStruct(Tuple{Float64, Int64}, Any[Float64, Core.Const(2)])
# │         (L = Core.getfield(%20, 1))
# │         (@_5 = Core.getfield(%20, 2))
# │   %23 = @_5::Core.Const(2)
# │   %24 = Base.indexed_iterate(%19, 2, %23)::Core.PartialStruct(Tuple{SVector{3, Float64}, Int64}, Any[SVector{3, Float64}, Core.Const(3)])
# │         (∇ᵤL = Core.getfield(%24, 1))
# │   %26 = Main.SVector::Core.Const(SVector)
# │   %27 = Main.Float64::Core.Const(Float64)
# │   %28 = Core.apply_type(%26, 3, %27)::Core.Const(SVector{3, Float64})
# │   %29 = ∇ᵤL::SVector{3, Float64}
# │   %30 = Base.getindex(%29, 1)::Float64
# │   %31 = ∇ᵤL::SVector{3, Float64}
# │   %32 = Base.getindex(%31, 2)::Float64
# │   %33 = Main.:/::Core.Const(/)
# │   %34 = ∇ᵤL::SVector{3, Float64}
# │   %35 = Base.getindex(%34, 3)::Float64
# │   %36 = (%33)(%35, H)::Float64
# │         (∇L = (%28)(%30, %32, %36))
# │   %38 = L::Float64
# │   %39 = ∇L::SVector{3, Float64}
# │   %40 = Core.tuple(%38, %39)::Tuple{Float64, SVector{3, Float64}}
# └──       return %40

# %%
@code_warntype HL₂(0.1, 0.5, 0.3)
# Out:
# MethodInstance for HL₂(::Float64, ::Float64, ::Float64)
#   from HL₂(A::Float64, B₂::Float64, H::Float64) @ Main In[3]:113
# Arguments
#   #self#::Core.Const(Main.HL₂)
#   A::Float64
#   B₂::Float64
#   H::Float64
# Locals
#   @_5::Int64
#   HL::SMatrix{3, 3, Float64, 9}
#   HL²::MMatrix{3, 3, Float64, 9}
#   HL¹::MMatrix{3, 3, Float64, 9}
#   ∇L::SVector{3, Float64}
#   HᵤL::SMatrix{3, 3, Float64, 9}
#   ∇ᵤL::SVector{3, Float64}
#   L::Float64
#   i::Int64
#   u::SVector{3, Float64}
#   x::SVector{3, Float64}
# Body::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# 1 ─ %1  = Main.SVector::Core.Const(SVector)
# │   %2  = Main.Float64::Core.Const(Float64)
# │   %3  = Core.apply_type(%1, 3, %2)::Core.Const(SVector{3, Float64})
# │         (x = (%3)(A, B₂, H))
# │   %5  = Main.SVector::Core.Const(SVector)
# │   %6  = Main.Float64::Core.Const(Float64)
# │   %7  = Core.apply_type(%5, 3, %6)::Core.Const(SVector{3, Float64})
# │   %8  = Main.log::Core.Const(log)
# │   %9  = (%8)(H)::Float64
# │         (u = (%7)(A, B₂, %9))
# │   %11 = Main.get_L₂_series_index::Core.Const(Main.get_L₂_series_index)
# │   %12 = x::SVector{3, Float64}
# │         (i = (%11)(%12))
# │   %14 = Main.hessian::Core.Const(WaveGreen2D.Chebyshev.hessian)
# │   %15 = Main.L₂_series::Core.Const(ChebyshevSeries{Float64, 3}[3-D Chebyshev series of order (11, 18, 23), 3-D Chebyshev series of order (11, 18, 22), 3-D Chebyshev series of order (12, 20, 21), 3-D Chebyshev series of order (13, 21, 21)])
# │   %16 = i::Int64
# │   %17 = Base.getindex(%15, %16)::ChebyshevSeries{Float64, 3}
# │   %18 = u::SVector{3, Float64}
# │   %19 = (%14)(%17, %18)::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# │   %20 = Base.indexed_iterate(%19, 1)::Core.PartialStruct(Tuple{Float64, Int64}, Any[Float64, Core.Const(2)])
# │         (L = Core.getfield(%20, 1))
# │         (@_5 = Core.getfield(%20, 2))
# │   %23 = @_5::Core.Const(2)
# │   %24 = Base.indexed_iterate(%19, 2, %23)::Core.PartialStruct(Tuple{SVector{3, Float64}, Int64}, Any[SVector{3, Float64}, Core.Const(3)])
# │         (∇ᵤL = Core.getfield(%24, 1))
# │         (@_5 = Core.getfield(%24, 2))
# │   %27 = @_5::Core.Const(3)
# │   %28 = Base.indexed_iterate(%19, 3, %27)::Core.PartialStruct(Tuple{SMatrix{3, 3, Float64, 9}, Int64}, Any[SMatrix{3, 3, Float64, 9}, Core.Const(4)])
# │         (HᵤL = Core.getfield(%28, 1))
# │   %30 = Main.SVector::Core.Const(SVector)
# │   %31 = Main.Float64::Core.Const(Float64)
# │   %32 = Core.apply_type(%30, 3, %31)::Core.Const(SVector{3, Float64})
# │   %33 = ∇ᵤL::SVector{3, Float64}
# │   %34 = Base.getindex(%33, 1)::Float64
# │   %35 = ∇ᵤL::SVector{3, Float64}
# │   %36 = Base.getindex(%35, 2)::Float64
# │   %37 = Main.:/::Core.Const(/)
# │   %38 = ∇ᵤL::SVector{3, Float64}
# │   %39 = Base.getindex(%38, 3)::Float64
# │   %40 = (%37)(%39, H)::Float64
# │         (∇L = (%32)(%34, %36, %40))
# │   %42 = Main.zero::Core.Const(zero)
# │   %43 = Main.MMatrix::Core.Const(MMatrix)
# │   %44 = Main.Float64::Core.Const(Float64)
# │   %45 = Core.apply_type(%43, 3, 3, %44, 9)::Core.Const(MMatrix{3, 3, Float64, 9})
# │         (HL¹ = (%42)(%45))
# │   %47 = Main.:/::Core.Const(/)
# │   %48 = Main.:-::Core.Const(-)
# │   %49 = ∇ᵤL::SVector{3, Float64}
# │   %50 = Base.getindex(%49, 3)::Float64
# │   %51 = (%48)(%50)::Float64
# │   %52 = Main.:^::Core.Const(^)
# │   %53 = Core.apply_type(Base.Val, 2)::Core.Const(Val{2})
# │   %54 = (%53)()::Core.Const(Val{2}())
# │   %55 = Base.literal_pow(%52, H, %54)::Float64
# │   %56 = (%47)(%51, %55)::Float64
# │   %57 = HL¹::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │         Base.setindex!(%57, %56, 3, 3)
# │   %59 = Main.MMatrix::Core.Const(MMatrix)
# │   %60 = Main.Float64::Core.Const(Float64)
# │   %61 = Core.apply_type(%59, 3, 3, %60, 9)::Core.Const(MMatrix{3, 3, Float64, 9})
# │   %62 = HᵤL::SMatrix{3, 3, Float64, 9}
# │         (HL² = (%61)(%62))
# │   %64 = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %65 = Main.:(:)::Core.Const(Colon())
# │   %66 = Base.dotview(%64, 3, %65)::Core.PartialStruct(SizedVector{3, Float64, SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Int64, Base.Slice{SOneTo{3}}}, true}}, Any[Core.PartialStruct(SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Int64, Base.Slice{SOneTo{3}}}, true}, Any[Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}]), Core.Const((3, Base.Slice(SOneTo(3)))), Core.Const(0), Core.Const(3)])])
# │   %67 = Main.:*::Core.Const(*)
# │   %68 = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %69 = Main.:(:)::Core.Const(Colon())
# │   %70 = Base.getindex(%68, 3, %69)::Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}])
# │   %71 = Main.:/::Core.Const(/)
# │   %72 = (%71)(1, H)::Float64
# │   %73 = Base.broadcasted(%67, %70, %72)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{MVector{3, Float64}, Float64}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(*), Core.PartialStruct(Tuple{MVector{3, Float64}, Float64}, Any[Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}]), Float64]), Core.Const(nothing)])
# │         Base.materialize!(%66, %73)
# │   %75 = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %76 = Main.:(:)::Core.Const(Colon())
# │   %77 = Base.dotview(%75, %76, 3)::Core.PartialStruct(SizedVector{3, Float64, SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Base.Slice{SOneTo{3}}, Int64}, true}}, Any[Core.PartialStruct(SubArray{Float64, 1, MMatrix{3, 3, Float64, 9}, Tuple{Base.Slice{SOneTo{3}}, Int64}, true}, Any[Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}]), Core.Const((Base.Slice(SOneTo(3)), 3)), Core.Const(6), Core.Const(1)])])
# │   %78 = Main.:*::Core.Const(*)
# │   %79 = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %80 = Main.:(:)::Core.Const(Colon())
# │   %81 = Base.getindex(%79, %80, 3)::Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}])
# │   %82 = Main.:/::Core.Const(/)
# │   %83 = (%82)(1, H)::Float64
# │   %84 = Base.broadcasted(%78, %81, %83)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{MVector{3, Float64}, Float64}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(*), Core.PartialStruct(Tuple{MVector{3, Float64}, Float64}, Any[Core.PartialStruct(MVector{3, Float64}, Any[Tuple{Float64, Float64, Float64}]), Float64]), Core.Const(nothing)])
# │         Base.materialize!(%77, %84)
# │   %86 = Main.SMatrix::Core.Const(SMatrix)
# │   %87 = Main.Float64::Core.Const(Float64)
# │   %88 = Core.apply_type(%86, 3, 3, %87, 9)::Core.Const(SMatrix{3, 3, Float64, 9})
# │   %89 = Main.:+::Core.Const(+)
# │   %90 = HL¹::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %91 = HL²::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │   %92 = (%89)(%90, %91)::Core.PartialStruct(MMatrix{3, 3, Float64, 9}, Any[NTuple{9, Float64}])
# │         (HL = (%88)(%92))
# │   %94 = L::Float64
# │   %95 = ∇L::SVector{3, Float64}
# │   %96 = HL::SMatrix{3, 3, Float64, 9}
# │   %97 = Core.tuple(%94, %95, %96)::Tuple{Float64, SVector{3, Float64}, SMatrix{3, 3, Float64, 9}}
# └──       return %97

# %%
function C₁(x::SVector{3, Float64})
    if contains(C₁1, x)
        return C₁1(x)
    elseif contains(C₁2, x)
        return C₁2(x)
    elseif contains(C₁3, x)
        return C₁3(x)
    else
        throw(DomainError(x))
    end
end


function C₁_gradient(x::SVector{3, Float64})
    if contains(C₁1, x)
        return gradient(C₁1, x)
    elseif contains(C₁2, x)
        return gradient(C₁2, x)
    elseif contains(C₁3, x)
        return gradient(C₁3, x)
    else
        throw(DomainError(x))
    end
end


function C₁_hessian(x::SVector{3, Float64})
    if contains(C₁1, x)
        return hessian(C₁1, x)
    elseif contains(C₁2, x)
        return hessian(C₁2, x)
    elseif contains(C₁3, x)
        return hessian(C₁3, x)
    else
        throw(DomainError(x))
    end
end


function C₂(x::SVector{3, Float64})
    if contains(C₂1, x)
        return C₂1(x)
    elseif contains(C₂2, x)
        return C₂2(x)
    elseif contains(C₂3, x)
        return C₂3(x)
    elseif contains(C₂4, x)
        return C₂4(x)
    else
        throw(DomainError(x))
    end
end


function C₂_gradient(x::SVector{3, Float64})
    if contains(C₂1, x)
        return gradient(C₂1, x)
    elseif contains(C₂2, x)
        return gradient(C₂2, x)
    elseif contains(C₂3, x)
        return gradient(C₂3, x)
    elseif contains(C₂4, x)
        return gradient(C₂4, x)
    else
        throw(DomainError(x))
    end
end


function C₂_hessian(x::SVector{3, Float64})
    if contains(C₂1, x)
        return hessian(C₂1, x)
    elseif contains(C₂2, x)
        return hessian(C₂2, x)
    elseif contains(C₂3, x)
        return hessian(C₂3, x)
    elseif contains(C₂4, x)
        return hessian(C₂4, x)
    else
        throw(DomainError(x))
    end
end;

# %%
tol_L = 10^2 * eps()
tol_∇L = 10^4 * eps()
tol_HL = 10^6 * eps();

# %%
@testset "L₁ Chebyshev" begin
    @load "../test/data/l1_test_data.jld2" x1 L1 ∇L1 HL1

    npoints = length(x1)
    
    C1 = Vector{Float64}(undef, npoints)
    C1g = Vector{Float64}(undef, npoints)
    C1h = Vector{Float64}(undef, npoints)
    
    ∇C1 = Matrix{Float64}(undef, npoints, 3)
    ∇C1h = Matrix{Float64}(undef, npoints, 3)
    
    HC1 = Array{Float64, 3}(undef, npoints, 3, 3)

    for i in 1:npoints
        y₁ = C₁(x1[i])
        y₂, ∇y₂ = C₁_gradient(x1[i])
        y₃, ∇y₃, Hy₃ = C₁_hessian(x1[i])
    
        C1[i] = y₁
        C1g[i] = y₂
        C1h[i] = y₃
        ∇C1[i, :] .= ∇y₂
        ∇C1h[i, :] .= ∇y₃
        HC1[i, :, :] .= Hy₃
    end

    # Test if ChebyshevSeries, gradient and hessian return the same value of L₁
    @test C1 == C1g
    @test C1 == C1h

    # Test if gradient and hessian return the same value of ∇L₁
    @test ∇C1 == ∇C1h

    @test all(isapprox.(L1, C1; rtol=tol_L, atol=tol_L))
    @test all(isapprox.(∇L1, ∇C1; rtol=tol_∇L, atol=tol_∇L))
    @test all(isapprox.(HL1, HC1; rtol=tol_HL, atol=tol_HL))
end
# Out:
# Test Summary: | Pass  Total  Time
# L₁ Chebyshev  |    6      6  8.4s
# Test.DefaultTestSet("L₁ Chebyshev", Any[], 6, false, false, true, 1.782325593430538e9, 1.782325601793092e9, false, "In[7]", Random.Xoshiro(0xcf472b10b95f8e61, 0x89133bd8ee98d2f4, 0x9f1f89be3af83969, 0x6217d4e58df07103, 0x34c561998d963d5f))

# %%
@testset "L₂ Chebyshev" begin
    @load "../test/data/l2_test_data.jld2" x2 L2 ∇L2 HL2

    npoints = length(x2)
    
    C2 = Vector{Float64}(undef, npoints)
    C2g = Vector{Float64}(undef, npoints)
    C2h = Vector{Float64}(undef, npoints)
    
    ∇C2 = Matrix{Float64}(undef, npoints, 3)
    ∇C2h = Matrix{Float64}(undef, npoints, 3)
    
    HC2 = Array{Float64, 3}(undef, npoints, 3, 3)

    for i in 1:npoints
        y₁ = C₂(x2[i])
        y₂, ∇y₂ = C₂_gradient(x2[i])
        y₃, ∇y₃, Hy₃ = C₂_hessian(x2[i])
    
        C2[i] = y₁
        C2g[i] = y₂
        C2h[i] = y₃
        ∇C2[i, :] .= ∇y₂
        ∇C2h[i, :] .= ∇y₃
        HC2[i, :, :] .= Hy₃
    end

    # Test if ChebyshevSeries, gradient and hessian return the same value of L₁
    @test C2 == C2g
    @test C2 == C2h

    # Test if gradient and hessian return the same value of ∇L₁
    @test ∇C2 == ∇C2h

    @test all(isapprox.(L2, C2; rtol=tol_L, atol=tol_L))
    @test all(isapprox.(∇L2, ∇C2; rtol=tol_∇L, atol=tol_∇L))
    @test all(isapprox.(HL2, HC2; rtol=tol_HL, atol=tol_HL))
end
# Out:
# Test Summary: | Pass  Total  Time
# L₂ Chebyshev  |    6      6  0.2s
# Test.DefaultTestSet("L₂ Chebyshev", Any[], 6, false, false, true, 1.782325602176509e9, 1.782325602334543e9, false, "In[8]", Random.Xoshiro(0xcf472b10b95f8e61, 0x89133bd8ee98d2f4, 0x9f1f89be3af83969, 0x6217d4e58df07103, 0x34c561998d963d5f))
