# %%
import Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#   Activating project at `~/repos/WaveGreen2D/notebooks`
# Precompiling packages...
#    4231.2 ms  ✓ WaveGreen2D
#   1 dependency successfully precompiled in 6 seconds. 304 already precompiled.

# %%
using WaveGreen2D: wave, setwave!

# %%
setwave!(depth=50, frequency=2π/10)
# Out:
# [ Info: Wave parameters h = 50.0 m, ω = 0.63 rad/s, g = 9.81 m/s²

# %%
wave.kₙ
# Out:
# (0.04909596504381295, 0.11914706139344662, 0.1841920560070159, 0.24811037712455697, 0.3115895379619896, 0.37485143994701897, 0.4379898701313364, 0.5010513764768413, 0.5640617044685345, 0.6270362569243205)
