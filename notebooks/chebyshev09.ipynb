# %%
import Pkg
Pkg.activate("../chebcoefs")
Pkg.instantiate()
# Out:
#   Activating project at `~/repos/WaveGreen2D/chebcoefs`

# %%
using StaticArrays
using FastChebInterp

include("Chebyshev.jl")
using .Chebyshev
import .Chebyshev: contains

# %%
function fx(x)
    return sin.(x)
end

function ∇fx(x)
    return cos.(x)
end

function Hfx(x)
    return -sin.(x)
end

function fu(u)
    x = u.^2
    return sin.(x)
end

function ∇fu(u)
    x = u.^2
    return cos.(x)
end

function Hfu(u)
    x = u.^2
    return -sin.(x)
end

function u(x::SVector{1, Float64})
    return x.^0.5
end

function ∇u(x::SVector{1, Float64})
    return reshape(0.5*x.^-0.5, Size(1, 1))
end

function Hu(x::SVector{1, Float64})
    return reshape(-0.25*x.^-1.5, Size(1, 1, 1))
end

function u_to_x(u::SVector{1, Float64})
    return u.^2
end

x1, x2, x3 = SA[0.0], SA[0.25*π], SA[0.5*π]
u1, u2, u3 = u(x1), u(x2), u(x3)

n = 50

tf1 = Transformation(u, ∇u, Hu)

xc1 = chebpoints(n, u1[], u2[])
cb1 = chebinterp(fu.(xc1), u1[], u2[])
cs1 = ChebyshevSeries(cb1.coefs, u1[], u2[], tf1)

xc2 = chebpoints(n, x2[], x3[])
cb2 = chebinterp(fx.(xc2), x2[], x3[])
cs2 = ChebyshevSeries(cb2.coefs, x2[], x3[])

cc = ChebyshevCluster(cs1, cs2);

# %%
x4 = 0.5*(x1 + x2)
x5 = 0.5*(x2 + x3)

u4 = u(x4)
u5 = u(x5);

# %%
cs1(x4[])
# Out:
# 0.3826834323650898

# %%
gradient(cs1, x4[])
# Out:
# (0.3826834323650898, 0.9238795325112872)

# %%
hessian(cs1, x4[])
# Out:
# (0.3826834323650898, 0.9238795325112872, -0.38268343236507096)

# %%
fx(x4)
# Out:
# 1-element SVector{1, Float64} with indices SOneTo(1):
#  0.3826834323650898

# %%
∇fx(x4)
# Out:
# 1-element SVector{1, Float64} with indices SOneTo(1):
#  0.9238795325112867

# %%
Hfx(x4)
# Out:
# 1-element SVector{1, Float64} with indices SOneTo(1):
#  -0.3826834323650898

# %%
cs2(x5[])
# Out:
# 0.9238795325112868

# %%
gradient(cs2, x5[])
# Out:
# (0.9238795325112868, 0.38268343236508934)

# %%
hessian(cs2, x5[])
# Out:
# (0.9238795325112868, 0.38268343236508934, -0.9238795325112718)

# %%
fx(x5)
# Out:
# 1-element SVector{1, Float64} with indices SOneTo(1):
#  0.9238795325112867

# %%
∇fx(x5)
# Out:
# 1-element SVector{1, Float64} with indices SOneTo(1):
#  0.38268343236508984

# %%
Hfx(x5)
# Out:
# 1-element SVector{1, Float64} with indices SOneTo(1):
#  -0.9238795325112867

# %%
@code_warntype cs1(x4)
# Out:
# MethodInstance for (::ChebyshevSeries{Float64, 1, Transformation{typeof(u), typeof(∇u), typeof(Hu)}})(::SVector{1, Float64})
#   from (f::ChebyshevSeries{T, N})(x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/clenshaw.jl:66
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   f::ChebyshevSeries{Float64, 1, Transformation{typeof(u), typeof(∇u), typeof(Hu)}}
#   x::SVector{1, Float64}
# Locals
#   y::Float64
#   x̄::SVector{1, Float64}
# Body::Float64
# 1 ─ %1 = Main.Chebyshev.normalize::Core.Const(Main.Chebyshev.normalize)
# │        (x̄ = (%1)(f, x))
# │   %3 = Main.Chebyshev.clenshaw::Core.Const(Main.Chebyshev.clenshaw)
# │   %4 = Base.getproperty(f, :coefs)::Vector{Float64}
# │   %5 = x̄::SVector{1, Float64}
# │        (y = (%3)(%4, %5))
# │   %7 = y::Float64
# └──      return %7

# %%
@code_warntype gradient(cs1, x4)
# Out:
# MethodInstance for gradient(::ChebyshevSeries{Float64, 1, Transformation{typeof(u), typeof(∇u), typeof(Hu)}}, ::SVector{1, Float64})
#   from gradient(f::ChebyshevSeries{T, N}, x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/gradient.jl:79
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   #self#::Core.Const(Main.Chebyshev.gradient)
#   f::ChebyshevSeries{Float64, 1, Transformation{typeof(u), typeof(∇u), typeof(Hu)}}
#   x::SVector{1, Float64}
# Locals
#   #7::Main.Chebyshev.var"#gradient##0#gradient##1"{Tuple{Float64, Float64}}
#   ∇y::SVector{1, Float64}
#   ∇ₓu::SMatrix{1, 1, Float64, 1}
#   ∇ᵤy::SVector{1, Float64}
#   y::Float64
#   res::Tuple{Float64, Float64}
#   dx̄_dx::SVector{1, Float64}
#   x̄::SVector{1, Float64}
# Body::Tuple{Float64, SVector{1, Float64}}
# 1 ─ %1  = Main.Chebyshev.normalize::Core.Const(Main.Chebyshev.normalize)
# │         (x̄ = (%1)(f, x))
# │   %3  = Main.Chebyshev.:/::Core.Const(/)
# │   %4  = Main.Chebyshev.:-::Core.Const(-)
# │   %5  = Base.getproperty(f, :ub)::SVector{1, Float64}
# │   %6  = Base.getproperty(f, :lb)::SVector{1, Float64}
# │   %7  = Base.broadcasted(%4, %5, %6)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │   %8  = Base.broadcasted(%3, 2.0, %7)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(/), Tuple{Float64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(/), Core.PartialStruct(Tuple{Float64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}, Any[Core.Const(2.0), Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}]), Core.Const(nothing)])
# │         (dx̄_dx = Base.materialize(%8))
# │   %10 = Main.Chebyshev.gradient_clenshaw::Core.Const(Main.Chebyshev.gradient_clenshaw)
# │   %11 = Base.getproperty(f, :coefs)::Vector{Float64}
# │   %12 = x̄::SVector{1, Float64}
# │         (res = (%10)(%11, %12))
# │   %14 = res::Tuple{Float64, Float64}
# │         (y = Base.getindex(%14, 1))
# │   %16 = Main.Chebyshev.:*::Core.Const(*)
# │   %17 = Main.Chebyshev.SVector::Core.Const(SVector)
# │   %18 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %19 = $(Expr(:static_parameter, 1))::Core.Const(Float64)
# │   %20 = Core.apply_type(%17, %18, %19)::Core.Const(SVector{1, Float64})
# │   %21 = Main.Chebyshev.ntuple::Core.Const(ntuple)
# │   %22 = Main.Chebyshev.:(var"#gradient##0#gradient##1")::Core.Const(Main.Chebyshev.var"#gradient##0#gradient##1")
# │   %23 = res::Tuple{Float64, Float64}
# │   %24 = Core._typeof_captured_variable(%23)::Core.Const(Tuple{Float64, Float64})
# │   %25 = Core.apply_type(%22, %24)::Core.Const(Main.Chebyshev.var"#gradient##0#gradient##1"{Tuple{Float64, Float64}})
# │   %26 = res::Tuple{Float64, Float64}
# │         (#7 = %new(%25, %26))
# │   %28 = #7::Main.Chebyshev.var"#gradient##0#gradient##1"{Tuple{Float64, Float64}}
# │   %29 = Main.Chebyshev.Val::Core.Const(Val)
# │   %30 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %31 = (%29)(%30)::Core.Const(Val{1}())
# │   %32 = (%21)(%28, %31)::Tuple{Float64}
# │   %33 = (%20)(%32)::SVector{1, Float64}
# │   %34 = dx̄_dx::SVector{1, Float64}
# │   %35 = Base.broadcasted(%16, %33, %34)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │         (∇ᵤy = Base.materialize(%35))
# │   %37 = Base.getproperty(f, :tf)::Core.Const(Transformation{typeof(u), typeof(∇u), typeof(Hu)}(Main.u, Main.∇u, Main.Hu))
# │   %38 = Base.getproperty(%37, :∇u)::Core.Const(Main.∇u)
# │         (∇ₓu = (%38)(x))
# │   %40 = Main.Chebyshev.:*::Core.Const(*)
# │   %41 = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %42 = ∇ₓu::SMatrix{1, 1, Float64, 1}
# │   %43 = (%41)(%42)::SMatrix{1, 1, Float64, 1}
# │   %44 = ∇ᵤy::SVector{1, Float64}
# │         (∇y = (%40)(%43, %44))
# │   %46 = y::Float64
# │   %47 = ∇y::SVector{1, Float64}
# │   %48 = Core.tuple(%46, %47)::Tuple{Float64, SVector{1, Float64}}
# └──       return %48

# %%
@code_warntype hessian(cs1, x4)
# Out:
# MethodInstance for hessian(::ChebyshevSeries{Float64, 1, Transformation{typeof(u), typeof(∇u), typeof(Hu)}}, ::SVector{1, Float64})
#   from hessian(f::ChebyshevSeries{T, N}, x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/hessian.jl:119
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   #self#::Core.Const(Main.Chebyshev.hessian)
#   f::ChebyshevSeries{Float64, 1, Transformation{typeof(u), typeof(∇u), typeof(Hu)}}
#   x::SVector{1, Float64}
# Locals
#   #16::Main.Chebyshev.var"#hessian##8#hessian##9"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
#   #15::Main.Chebyshev.var"#hessian##6#hessian##7"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
#   #14::Main.Chebyshev.var"#hessian##2#hessian##3"
#   #12::Main.Chebyshev.var"#hessian##0#hessian##1"
#   Hy::SMatrix{1, 1, Float64, 1}
#   ∇y::SVector{1, Float64}
#   Hₓu::SArray{Tuple{1, 1, 1}, Float64, 3, 1}
#   ∇ₓu::SMatrix{1, 1, Float64, 1}
#   Hᵤy::SMatrix{1, 1, Float64, 1}
#   Hᵤy_vec::SVector{1, Float64}
#   ∇ᵤy::SVector{1, Float64}
#   y::Float64
#   res::Tuple{Float64, Float64, Float64}
#   hidx::Vector{Int64}
#   gidx::Vector{Int64}
#   K::Int64
#   dx̄_dx::SVector{1, Float64}
#   x̄::SVector{1, Float64}
# Body::Tuple{Float64, SVector{1, Float64}, SMatrix{1, 1, Float64, 1}}
# 1 ─ %1   = Main.Chebyshev.normalize::Core.Const(Main.Chebyshev.normalize)
# │          (x̄ = (%1)(f, x))
# │   %3   = Main.Chebyshev.:/::Core.Const(/)
# │   %4   = Main.Chebyshev.:-::Core.Const(-)
# │   %5   = Base.getproperty(f, :ub)::SVector{1, Float64}
# │   %6   = Base.getproperty(f, :lb)::SVector{1, Float64}
# │   %7   = Base.broadcasted(%4, %5, %6)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │   %8   = Base.broadcasted(%3, 2, %7)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(/), Tuple{Int64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(/), Core.PartialStruct(Tuple{Int64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}, Any[Core.Const(2), Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}]), Core.Const(nothing)])
# │          (dx̄_dx = Base.materialize(%8))
# │   %10  = Main.Chebyshev.:÷::Core.Const(div)
# │   %11  = Main.Chebyshev.:*::Core.Const(*)
# │   %12  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %13  = Main.Chebyshev.:+::Core.Const(+)
# │   %14  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %15  = (%13)(%14, 1)::Core.Const(2)
# │   %16  = (%11)(%12, %15)::Core.Const(2)
# │          (K = (%10)(%16, 2))
# │   %18  = Main.Chebyshev.:(var"#hessian##0#hessian##1")::Core.Const(Main.Chebyshev.var"#hessian##0#hessian##1")
# │          (#12 = %new(%18))
# │   %20  = #12::Core.Const(Main.Chebyshev.var"#hessian##0#hessian##1"())
# │   %21  = Main.Chebyshev.:(:)::Core.Const(Colon())
# │   %22  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %23  = (%21)(1, %22)::Core.Const(1:1)
# │   %24  = Base.Generator(%20, %23)::Core.Const(Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##0#hessian##1"}(Main.Chebyshev.var"#hessian##0#hessian##1"(), 1:1))
# │          (gidx = Base.collect(%24))
# │   %26  = Main.Chebyshev.:(var"#hessian##2#hessian##3")::Core.Const(Main.Chebyshev.var"#hessian##2#hessian##3")
# │          (#14 = %new(%26))
# │   %28  = #14::Core.Const(Main.Chebyshev.var"#hessian##2#hessian##3"())
# │   %29  = Main.Chebyshev.:(:)::Core.Const(Colon())
# │   %30  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %31  = (%29)(1, %30)::Core.Const(1:1)
# │   %32  = Base.Generator(%28, %31)::Core.Const(Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##2#hessian##3"}(Main.Chebyshev.var"#hessian##2#hessian##3"(), 1:1))
# │   %33  = Base.Flatten(%32)::Core.Const(Base.Iterators.Flatten{Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##2#hessian##3"}}(Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##2#hessian##3"}(Main.Chebyshev.var"#hessian##2#hessian##3"(), 1:1)))
# │          (hidx = Base.collect(%33))
# │   %35  = Main.Chebyshev.hessian_clenshaw::Core.Const(Main.Chebyshev.hessian_clenshaw)
# │   %36  = Base.getproperty(f, :coefs)::Vector{Float64}
# │   %37  = x̄::SVector{1, Float64}
# │          (res = (%35)(%36, %37))
# │   %39  = res::Tuple{Float64, Float64, Float64}
# │          (y = Base.getindex(%39, 1))
# │   %41  = Main.Chebyshev.:*::Core.Const(*)
# │   %42  = Main.Chebyshev.SVector::Core.Const(SVector)
# │   %43  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %44  = $(Expr(:static_parameter, 1))::Core.Const(Float64)
# │   %45  = Core.apply_type(%42, %43, %44)::Core.Const(SVector{1, Float64})
# │   %46  = Main.Chebyshev.ntuple::Core.Const(ntuple)
# │   %47  = Main.Chebyshev.:(var"#hessian##6#hessian##7")::Core.Const(Main.Chebyshev.var"#hessian##6#hessian##7")
# │   %48  = res::Tuple{Float64, Float64, Float64}
# │   %49  = Core._typeof_captured_variable(%48)::Core.Const(Tuple{Float64, Float64, Float64})
# │   %50  = gidx::Vector{Int64}
# │   %51  = Core._typeof_captured_variable(%50)::Core.Const(Vector{Int64})
# │   %52  = Core.apply_type(%47, %49, %51)::Core.Const(Main.Chebyshev.var"#hessian##6#hessian##7"{Tuple{Float64, Float64, Float64}, Vector{Int64}})
# │   %53  = res::Tuple{Float64, Float64, Float64}
# │   %54  = gidx::Vector{Int64}
# │          (#15 = %new(%52, %53, %54))
# │   %56  = #15::Main.Chebyshev.var"#hessian##6#hessian##7"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
# │   %57  = Main.Chebyshev.Val::Core.Const(Val)
# │   %58  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %59  = (%57)(%58)::Core.Const(Val{1}())
# │   %60  = (%46)(%56, %59)::Tuple{Float64}
# │   %61  = (%45)(%60)::SVector{1, Float64}
# │   %62  = dx̄_dx::SVector{1, Float64}
# │   %63  = Base.broadcasted(%41, %61, %62)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │          (∇ᵤy = Base.materialize(%63))
# │   %65  = Main.Chebyshev.SVector::Core.Const(SVector)
# │   %66  = K::Core.Const(1)
# │   %67  = $(Expr(:static_parameter, 1))::Core.Const(Float64)
# │   %68  = Core.apply_type(%65, %66, %67)::Core.Const(SVector{1, Float64})
# │   %69  = Main.Chebyshev.ntuple::Core.Const(ntuple)
# │   %70  = Main.Chebyshev.:(var"#hessian##8#hessian##9")::Core.Const(Main.Chebyshev.var"#hessian##8#hessian##9")
# │   %71  = res::Tuple{Float64, Float64, Float64}
# │   %72  = Core._typeof_captured_variable(%71)::Core.Const(Tuple{Float64, Float64, Float64})
# │   %73  = hidx::Vector{Int64}
# │   %74  = Core._typeof_captured_variable(%73)::Core.Const(Vector{Int64})
# │   %75  = Core.apply_type(%70, %72, %74)::Core.Const(Main.Chebyshev.var"#hessian##8#hessian##9"{Tuple{Float64, Float64, Float64}, Vector{Int64}})
# │   %76  = res::Tuple{Float64, Float64, Float64}
# │   %77  = hidx::Vector{Int64}
# │          (#16 = %new(%75, %76, %77))
# │   %79  = #16::Main.Chebyshev.var"#hessian##8#hessian##9"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
# │   %80  = Main.Chebyshev.Val::Core.Const(Val)
# │   %81  = K::Core.Const(1)
# │   %82  = (%80)(%81)::Core.Const(Val{1}())
# │   %83  = (%69)(%79, %82)::Tuple{Float64}
# │          (Hᵤy_vec = (%68)(%83))
# │   %85  = Main.Chebyshev.:*::Core.Const(*)
# │   %86  = Main.Chebyshev.:*::Core.Const(*)
# │   %87  = Main.Chebyshev.symmatrix::Core.Const(Main.Chebyshev.symmatrix)
# │   %88  = Hᵤy_vec::SVector{1, Float64}
# │   %89  = Main.Chebyshev.Val::Core.Const(Val)
# │   %90  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %91  = (%89)(%90)::Core.Const(Val{1}())
# │   %92  = (%87)(%88, %91)::SMatrix{1, 1, Float64, 1}
# │   %93  = dx̄_dx::SVector{1, Float64}
# │   %94  = Base.broadcasted(%86, %92, %93)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{2}, Nothing, typeof(*), Tuple{SMatrix{1, 1, Float64, 1}, SVector{1, Float64}}}
# │   %95  = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %96  = dx̄_dx::SVector{1, Float64}
# │   %97  = (%95)(%96)::LinearAlgebra.Adjoint{Float64, SVector{1, Float64}}
# │   %98  = Base.broadcasted(%85, %94, %97)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{2}, Nothing, typeof(*), Tuple{Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{2}, Nothing, typeof(*), Tuple{SMatrix{1, 1, Float64, 1}, SVector{1, Float64}}}, LinearAlgebra.Adjoint{Float64, SVector{1, Float64}}}}
# │          (Hᵤy = Base.materialize(%98))
# │   %100 = Base.getproperty(f, :tf)::Core.Const(Transformation{typeof(u), typeof(∇u), typeof(Hu)}(Main.u, Main.∇u, Main.Hu))
# │   %101 = Base.getproperty(%100, :∇u)::Core.Const(Main.∇u)
# │          (∇ₓu = (%101)(x))
# │   %103 = Base.getproperty(f, :tf)::Core.Const(Transformation{typeof(u), typeof(∇u), typeof(Hu)}(Main.u, Main.∇u, Main.Hu))
# │   %104 = Base.getproperty(%103, :Hu)::Core.Const(Main.Hu)
# │          (Hₓu = (%104)(x))
# │   %106 = Main.Chebyshev.:*::Core.Const(*)
# │   %107 = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %108 = ∇ₓu::SMatrix{1, 1, Float64, 1}
# │   %109 = (%107)(%108)::SMatrix{1, 1, Float64, 1}
# │   %110 = ∇ᵤy::SVector{1, Float64}
# │          (∇y = (%106)(%109, %110))
# │   %112 = Main.Chebyshev.:+::Core.Const(+)
# │   %113 = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %114 = Main.Chebyshev.reshape::Core.Const(reshape)
# │   %115 = Main.Chebyshev.:*::Core.Const(*)
# │   %116 = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %117 = Main.Chebyshev.reshape::Core.Const(reshape)
# │   %118 = Hₓu::SArray{Tuple{1, 1, 1}, Float64, 3, 1}
# │   %119 = Main.Chebyshev.Size::Core.Const(Size)
# │   %120 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %121 = Main.Chebyshev.:^::Core.Const(^)
# │   %122 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %123 = Core.apply_type(Base.Val, 2)::Core.Const(Val{2})
# │   %124 = (%123)()::Core.Const(Val{2}())
# │   %125 = Base.literal_pow(%121, %122, %124)::Core.Const(1)
# │   %126 = (%119)(%120, %125)::Core.Const(Size(1, 1))
# │   %127 = (%117)(%118, %126)::SMatrix{1, 1, Float64, 1}
# │   %128 = (%116)(%127)::SMatrix{1, 1, Float64, 1}
# │   %129 = ∇ᵤy::SVector{1, Float64}
# │   %130 = (%115)(%128, %129)::SVector{1, Float64}
# │   %131 = Main.Chebyshev.Size::Core.Const(Size)
# │   %132 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %133 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %134 = (%131)(%132, %133)::Core.Const(Size(1, 1))
# │   %135 = (%114)(%130, %134)::SMatrix{1, 1, Float64, 1}
# │   %136 = (%113)(%135)::SMatrix{1, 1, Float64, 1}
# │   %137 = Main.Chebyshev.:*::Core.Const(*)
# │   %138 = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %139 = ∇ₓu::SMatrix{1, 1, Float64, 1}
# │   %140 = (%138)(%139)::SMatrix{1, 1, Float64, 1}
# │   %141 = Hᵤy::SMatrix{1, 1, Float64, 1}
# │   %142 = ∇ₓu::SMatrix{1, 1, Float64, 1}
# │   %143 = (%137)(%140, %141, %142)::SMatrix{1, 1, Float64, 1}
# │          (Hy = (%112)(%136, %143))
# │   %145 = y::Float64
# │   %146 = ∇y::SVector{1, Float64}
# │   %147 = Hy::SMatrix{1, 1, Float64, 1}
# │   %148 = Core.tuple(%145, %146, %147)::Tuple{Float64, SVector{1, Float64}, SMatrix{1, 1, Float64, 1}}
# └──        return %148

# %%
@code_warntype cs2(x5)
# Out:
# MethodInstance for (::ChebyshevSeries{Float64, 1, Transformation{Main.Chebyshev.var"#u#ChebyshevSeries##0"{1, Float64}, Main.Chebyshev.var"#∇u#ChebyshevSeries##1"{1, Float64}, Main.Chebyshev.var"#Hu#ChebyshevSeries##2"{1, Float64}}})(::SVector{1, Float64})
#   from (f::ChebyshevSeries{T, N})(x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/clenshaw.jl:66
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   f::ChebyshevSeries{Float64, 1, Transformation{Main.Chebyshev.var"#u#ChebyshevSeries##0"{1, Float64}, Main.Chebyshev.var"#∇u#ChebyshevSeries##1"{1, Float64}, Main.Chebyshev.var"#Hu#ChebyshevSeries##2"{1, Float64}}}
#   x::SVector{1, Float64}
# Locals
#   y::Float64
#   x̄::SVector{1, Float64}
# Body::Float64
# 1 ─ %1 = Main.Chebyshev.normalize::Core.Const(Main.Chebyshev.normalize)
# │        (x̄ = (%1)(f, x))
# │   %3 = Main.Chebyshev.clenshaw::Core.Const(Main.Chebyshev.clenshaw)
# │   %4 = Base.getproperty(f, :coefs)::Vector{Float64}
# │   %5 = x̄::SVector{1, Float64}
# │        (y = (%3)(%4, %5))
# │   %7 = y::Float64
# └──      return %7

# %%
@code_warntype gradient(cs2, x5)
# Out:
# MethodInstance for gradient(::ChebyshevSeries{Float64, 1, Transformation{Main.Chebyshev.var"#u#ChebyshevSeries##0"{1, Float64}, Main.Chebyshev.var"#∇u#ChebyshevSeries##1"{1, Float64}, Main.Chebyshev.var"#Hu#ChebyshevSeries##2"{1, Float64}}}, ::SVector{1, Float64})
#   from gradient(f::ChebyshevSeries{T, N}, x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/gradient.jl:79
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   #self#::Core.Const(Main.Chebyshev.gradient)
#   f::ChebyshevSeries{Float64, 1, Transformation{Main.Chebyshev.var"#u#ChebyshevSeries##0"{1, Float64}, Main.Chebyshev.var"#∇u#ChebyshevSeries##1"{1, Float64}, Main.Chebyshev.var"#Hu#ChebyshevSeries##2"{1, Float64}}}
#   x::SVector{1, Float64}
# Locals
#   #8::Main.Chebyshev.var"#gradient##0#gradient##1"{Tuple{Float64, Float64}}
#   ∇y::SVector{1, Float64}
#   y::Float64
#   res::Tuple{Float64, Float64}
#   dx̄_dx::SVector{1, Float64}
#   x̄::SVector{1, Float64}
# Body::Tuple{Float64, SVector{1, Float64}}
# 1 ─ %1  = Main.Chebyshev.normalize::Core.Const(Main.Chebyshev.normalize)
# │         (x̄ = (%1)(f, x))
# │   %3  = Main.Chebyshev.:/::Core.Const(/)
# │   %4  = Main.Chebyshev.:-::Core.Const(-)
# │   %5  = Base.getproperty(f, :ub)::SVector{1, Float64}
# │   %6  = Base.getproperty(f, :lb)::SVector{1, Float64}
# │   %7  = Base.broadcasted(%4, %5, %6)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │   %8  = Base.broadcasted(%3, 2.0, %7)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(/), Tuple{Float64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(/), Core.PartialStruct(Tuple{Float64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}, Any[Core.Const(2.0), Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}]), Core.Const(nothing)])
# │         (dx̄_dx = Base.materialize(%8))
# │   %10 = Main.Chebyshev.gradient_clenshaw::Core.Const(Main.Chebyshev.gradient_clenshaw)
# │   %11 = Base.getproperty(f, :coefs)::Vector{Float64}
# │   %12 = x̄::SVector{1, Float64}
# │         (res = (%10)(%11, %12))
# │   %14 = res::Tuple{Float64, Float64}
# │         (y = Base.getindex(%14, 1))
# │   %16 = Main.Chebyshev.:*::Core.Const(*)
# │   %17 = Main.Chebyshev.SVector::Core.Const(SVector)
# │   %18 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %19 = $(Expr(:static_parameter, 1))::Core.Const(Float64)
# │   %20 = Core.apply_type(%17, %18, %19)::Core.Const(SVector{1, Float64})
# │   %21 = Main.Chebyshev.ntuple::Core.Const(ntuple)
# │   %22 = Main.Chebyshev.:(var"#gradient##0#gradient##1")::Core.Const(Main.Chebyshev.var"#gradient##0#gradient##1")
# │   %23 = res::Tuple{Float64, Float64}
# │   %24 = Core._typeof_captured_variable(%23)::Core.Const(Tuple{Float64, Float64})
# │   %25 = Core.apply_type(%22, %24)::Core.Const(Main.Chebyshev.var"#gradient##0#gradient##1"{Tuple{Float64, Float64}})
# │   %26 = res::Tuple{Float64, Float64}
# │         (#8 = %new(%25, %26))
# │   %28 = #8::Main.Chebyshev.var"#gradient##0#gradient##1"{Tuple{Float64, Float64}}
# │   %29 = Main.Chebyshev.Val::Core.Const(Val)
# │   %30 = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %31 = (%29)(%30)::Core.Const(Val{1}())
# │   %32 = (%21)(%28, %31)::Tuple{Float64}
# │   %33 = (%20)(%32)::SVector{1, Float64}
# │   %34 = dx̄_dx::SVector{1, Float64}
# │   %35 = Base.broadcasted(%16, %33, %34)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │         (∇y = Base.materialize(%35))
# │   %37 = y::Float64
# │   %38 = ∇y::SVector{1, Float64}
# │   %39 = Core.tuple(%37, %38)::Tuple{Float64, SVector{1, Float64}}
# └──       return %39

# %%
@code_warntype hessian(cs2, x5)
# Out:
# MethodInstance for hessian(::ChebyshevSeries{Float64, 1, Transformation{Main.Chebyshev.var"#u#ChebyshevSeries##0"{1, Float64}, Main.Chebyshev.var"#∇u#ChebyshevSeries##1"{1, Float64}, Main.Chebyshev.var"#Hu#ChebyshevSeries##2"{1, Float64}}}, ::SVector{1, Float64})
#   from hessian(f::ChebyshevSeries{T, N}, x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/hessian.jl:119
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   #self#::Core.Const(Main.Chebyshev.hessian)
#   f::ChebyshevSeries{Float64, 1, Transformation{Main.Chebyshev.var"#u#ChebyshevSeries##0"{1, Float64}, Main.Chebyshev.var"#∇u#ChebyshevSeries##1"{1, Float64}, Main.Chebyshev.var"#Hu#ChebyshevSeries##2"{1, Float64}}}
#   x::SVector{1, Float64}
# Locals
#   #17::Main.Chebyshev.var"#hessian##8#hessian##9"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
#   #16::Main.Chebyshev.var"#hessian##6#hessian##7"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
#   #15::Main.Chebyshev.var"#hessian##2#hessian##3"
#   #13::Main.Chebyshev.var"#hessian##0#hessian##1"
#   Hy::SMatrix{1, 1, Float64, 1}
#   Hy_vec::SVector{1, Float64}
#   ∇y::SVector{1, Float64}
#   y::Float64
#   res::Tuple{Float64, Float64, Float64}
#   hidx::Vector{Int64}
#   gidx::Vector{Int64}
#   K::Int64
#   dx̄_dx::SVector{1, Float64}
#   x̄::SVector{1, Float64}
# Body::Tuple{Float64, SVector{1, Float64}, SMatrix{1, 1, Float64, 1}}
# 1 ─ %1   = Main.Chebyshev.normalize::Core.Const(Main.Chebyshev.normalize)
# │          (x̄ = (%1)(f, x))
# │   %3   = Main.Chebyshev.:/::Core.Const(/)
# │   %4   = Main.Chebyshev.:-::Core.Const(-)
# │   %5   = Base.getproperty(f, :ub)::SVector{1, Float64}
# │   %6   = Base.getproperty(f, :lb)::SVector{1, Float64}
# │   %7   = Base.broadcasted(%4, %5, %6)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │   %8   = Base.broadcasted(%3, 2, %7)::Core.PartialStruct(Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(/), Tuple{Int64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}}, Any[Core.Const(StaticArraysCore.StaticArrayStyle{1}()), Core.Const(/), Core.PartialStruct(Tuple{Int64, Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}}, Any[Core.Const(2), Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(-), Tuple{SVector{1, Float64}, SVector{1, Float64}}}]), Core.Const(nothing)])
# │          (dx̄_dx = Base.materialize(%8))
# │   %10  = Main.Chebyshev.:÷::Core.Const(div)
# │   %11  = Main.Chebyshev.:*::Core.Const(*)
# │   %12  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %13  = Main.Chebyshev.:+::Core.Const(+)
# │   %14  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %15  = (%13)(%14, 1)::Core.Const(2)
# │   %16  = (%11)(%12, %15)::Core.Const(2)
# │          (K = (%10)(%16, 2))
# │   %18  = Main.Chebyshev.:(var"#hessian##0#hessian##1")::Core.Const(Main.Chebyshev.var"#hessian##0#hessian##1")
# │          (#13 = %new(%18))
# │   %20  = #13::Core.Const(Main.Chebyshev.var"#hessian##0#hessian##1"())
# │   %21  = Main.Chebyshev.:(:)::Core.Const(Colon())
# │   %22  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %23  = (%21)(1, %22)::Core.Const(1:1)
# │   %24  = Base.Generator(%20, %23)::Core.Const(Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##0#hessian##1"}(Main.Chebyshev.var"#hessian##0#hessian##1"(), 1:1))
# │          (gidx = Base.collect(%24))
# │   %26  = Main.Chebyshev.:(var"#hessian##2#hessian##3")::Core.Const(Main.Chebyshev.var"#hessian##2#hessian##3")
# │          (#15 = %new(%26))
# │   %28  = #15::Core.Const(Main.Chebyshev.var"#hessian##2#hessian##3"())
# │   %29  = Main.Chebyshev.:(:)::Core.Const(Colon())
# │   %30  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %31  = (%29)(1, %30)::Core.Const(1:1)
# │   %32  = Base.Generator(%28, %31)::Core.Const(Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##2#hessian##3"}(Main.Chebyshev.var"#hessian##2#hessian##3"(), 1:1))
# │   %33  = Base.Flatten(%32)::Core.Const(Base.Iterators.Flatten{Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##2#hessian##3"}}(Base.Generator{UnitRange{Int64}, Main.Chebyshev.var"#hessian##2#hessian##3"}(Main.Chebyshev.var"#hessian##2#hessian##3"(), 1:1)))
# │          (hidx = Base.collect(%33))
# │   %35  = Main.Chebyshev.hessian_clenshaw::Core.Const(Main.Chebyshev.hessian_clenshaw)
# │   %36  = Base.getproperty(f, :coefs)::Vector{Float64}
# │   %37  = x̄::SVector{1, Float64}
# │          (res = (%35)(%36, %37))
# │   %39  = res::Tuple{Float64, Float64, Float64}
# │          (y = Base.getindex(%39, 1))
# │   %41  = Main.Chebyshev.:*::Core.Const(*)
# │   %42  = Main.Chebyshev.SVector::Core.Const(SVector)
# │   %43  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %44  = $(Expr(:static_parameter, 1))::Core.Const(Float64)
# │   %45  = Core.apply_type(%42, %43, %44)::Core.Const(SVector{1, Float64})
# │   %46  = Main.Chebyshev.ntuple::Core.Const(ntuple)
# │   %47  = Main.Chebyshev.:(var"#hessian##6#hessian##7")::Core.Const(Main.Chebyshev.var"#hessian##6#hessian##7")
# │   %48  = res::Tuple{Float64, Float64, Float64}
# │   %49  = Core._typeof_captured_variable(%48)::Core.Const(Tuple{Float64, Float64, Float64})
# │   %50  = gidx::Vector{Int64}
# │   %51  = Core._typeof_captured_variable(%50)::Core.Const(Vector{Int64})
# │   %52  = Core.apply_type(%47, %49, %51)::Core.Const(Main.Chebyshev.var"#hessian##6#hessian##7"{Tuple{Float64, Float64, Float64}, Vector{Int64}})
# │   %53  = res::Tuple{Float64, Float64, Float64}
# │   %54  = gidx::Vector{Int64}
# │          (#16 = %new(%52, %53, %54))
# │   %56  = #16::Main.Chebyshev.var"#hessian##6#hessian##7"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
# │   %57  = Main.Chebyshev.Val::Core.Const(Val)
# │   %58  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %59  = (%57)(%58)::Core.Const(Val{1}())
# │   %60  = (%46)(%56, %59)::Tuple{Float64}
# │   %61  = (%45)(%60)::SVector{1, Float64}
# │   %62  = dx̄_dx::SVector{1, Float64}
# │   %63  = Base.broadcasted(%41, %61, %62)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{1}, Nothing, typeof(*), Tuple{SVector{1, Float64}, SVector{1, Float64}}}
# │          (∇y = Base.materialize(%63))
# │   %65  = Main.Chebyshev.SVector::Core.Const(SVector)
# │   %66  = K::Core.Const(1)
# │   %67  = $(Expr(:static_parameter, 1))::Core.Const(Float64)
# │   %68  = Core.apply_type(%65, %66, %67)::Core.Const(SVector{1, Float64})
# │   %69  = Main.Chebyshev.ntuple::Core.Const(ntuple)
# │   %70  = Main.Chebyshev.:(var"#hessian##8#hessian##9")::Core.Const(Main.Chebyshev.var"#hessian##8#hessian##9")
# │   %71  = res::Tuple{Float64, Float64, Float64}
# │   %72  = Core._typeof_captured_variable(%71)::Core.Const(Tuple{Float64, Float64, Float64})
# │   %73  = hidx::Vector{Int64}
# │   %74  = Core._typeof_captured_variable(%73)::Core.Const(Vector{Int64})
# │   %75  = Core.apply_type(%70, %72, %74)::Core.Const(Main.Chebyshev.var"#hessian##8#hessian##9"{Tuple{Float64, Float64, Float64}, Vector{Int64}})
# │   %76  = res::Tuple{Float64, Float64, Float64}
# │   %77  = hidx::Vector{Int64}
# │          (#17 = %new(%75, %76, %77))
# │   %79  = #17::Main.Chebyshev.var"#hessian##8#hessian##9"{Tuple{Float64, Float64, Float64}, Vector{Int64}}
# │   %80  = Main.Chebyshev.Val::Core.Const(Val)
# │   %81  = K::Core.Const(1)
# │   %82  = (%80)(%81)::Core.Const(Val{1}())
# │   %83  = (%69)(%79, %82)::Tuple{Float64}
# │          (Hy_vec = (%68)(%83))
# │   %85  = Main.Chebyshev.:*::Core.Const(*)
# │   %86  = Main.Chebyshev.:*::Core.Const(*)
# │   %87  = Main.Chebyshev.symmatrix::Core.Const(Main.Chebyshev.symmatrix)
# │   %88  = Hy_vec::SVector{1, Float64}
# │   %89  = Main.Chebyshev.Val::Core.Const(Val)
# │   %90  = $(Expr(:static_parameter, 2))::Core.Const(1)
# │   %91  = (%89)(%90)::Core.Const(Val{1}())
# │   %92  = (%87)(%88, %91)::SMatrix{1, 1, Float64, 1}
# │   %93  = dx̄_dx::SVector{1, Float64}
# │   %94  = Base.broadcasted(%86, %92, %93)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{2}, Nothing, typeof(*), Tuple{SMatrix{1, 1, Float64, 1}, SVector{1, Float64}}}
# │   %95  = Main.Chebyshev.:var"'"::Core.Const(adjoint)
# │   %96  = dx̄_dx::SVector{1, Float64}
# │   %97  = (%95)(%96)::LinearAlgebra.Adjoint{Float64, SVector{1, Float64}}
# │   %98  = Base.broadcasted(%85, %94, %97)::Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{2}, Nothing, typeof(*), Tuple{Base.Broadcast.Broadcasted{StaticArraysCore.StaticArrayStyle{2}, Nothing, typeof(*), Tuple{SMatrix{1, 1, Float64, 1}, SVector{1, Float64}}}, LinearAlgebra.Adjoint{Float64, SVector{1, Float64}}}}
# │          (Hy = Base.materialize(%98))
# │   %100 = y::Float64
# │   %101 = ∇y::SVector{1, Float64}
# │   %102 = Hy::SMatrix{1, 1, Float64, 1}
# │   %103 = Core.tuple(%100, %101, %102)::Tuple{Float64, SVector{1, Float64}, SMatrix{1, 1, Float64, 1}}
# └──        return %103

# %%
println(cc(x4) - fx(x4)[])
println(cc(x5) - fx(x5)[])

println(cc(x4) - fu(u4)[])
println(cc(x5) - fu(u5)[])
# Out:
# 0.0
# 1.1102230246251565e-16
# 5.551115123125783e-17
# 2.220446049250313e-16

# %%
# g, ∇g = gradient(cc, x4[])

# println(g, ", ", fx(x4)[])
# println(∇g, ", ", ∇fx(x4)[])

# println(g - fx(x4)[])
# println(∇g - ∇fx(x4)[])

# %%
# g, ∇g = gradient(cc, x5[])

# println(g, ", ", fx(x5)[])
# println(∇g, ", ", ∇fx(x5)[])

# println(g - fx(x5)[])
# println(∇g - ∇fx(x5)[])

# %%
# g, ∇g, Hg = hessian(cc, x4[])

# println(g, ", ", fx(x4)[])
# println(∇g, ", ", ∇fx(x4)[])
# println(Hg, ", ", Hfx(x4)[])

# println(g - fx(x4)[])
# println(∇g - ∇fx(x4)[])
# println(Hg - Hfx(x4)[])

# %%
# g, ∇g, Hg = hessian(cc, x5[])

# println(g, ", ", fx(x5)[])
# println(∇g, ", ", ∇fx(x5)[])
# println(Hg, ", ", Hfx(x5)[])

# println(g - fx(x5)[])
# println(∇g - ∇fx(x5)[])
# println(Hg - Hfx(x5)[])

# %%
# @code_warntype cs1(x4)

# %%
# @code_warntype cs2(x5)

# %%
# @code_warntype tcs1(x4)

# %%
@code_warntype cc(x4)
# Out:
# MethodInstance for (::ChebyshevCluster{Float64, 1, Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, ChebyshevSeries{Float64, 1}}})(::SVector{1, Float64})
#   from (h::ChebyshevCluster{T, N, S} where S<:Tuple{Vararg{AbstractChebyshevSeries{T, N}}})(x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/clenshaw.jl:107
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   h::ChebyshevCluster{Float64, 1, Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, ChebyshevSeries{Float64, 1}}}
#   x::SVector{1, Float64}
# Locals
#   @_3::Union{Nothing, Tuple{Union{ChebyshevSeries{Float64, 1}, TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}}, Int64}}
#   s::Union{ChebyshevSeries{Float64, 1}, TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}}
# Body::Float64
# 1 ─ %1  = Base.getproperty(h, :series)::Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, ChebyshevSeries{Float64, 1}}
# │         (@_3 = Base.iterate(%1))
# │   %3  = @_3::Core.PartialStruct(Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, Int64}, Any[TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, Core.Const(2)])
# │   %4  = (%3 === nothing)::Core.Const(false)
# │   %5  = Base.not_int(%4)::Core.Const(true)
# └──       goto #7 if not %5
# 2 ┄ %7  = @_3::Union{Tuple{ChebyshevSeries{Float64, 1}, Int64}, Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, Int64}}
# │         (s = Core.getfield(%7, 1))
# │   %9  = Core.getfield(%7, 2)::Int64
# │   %10 = Main.Chebyshev.Bool::Core.Const(Bool)
# │   %11 = Main.Chebyshev.contains::Core.Const(Main.Chebyshev.contains)
# │   %12 = s::Union{ChebyshevSeries{Float64, 1}, TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}}
# │   %13 = (%11)(%12, x)::Bool
# │   %14 = (%10)(%13)::Bool
# └──       goto #5 if not %14
# 3 ─ %16 = s::Union{ChebyshevSeries{Float64, 1}, TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}}
# │   %17 = (%16)(x)::Float64
# └──       return %17
# 4 ─       Core.Const(:(goto %20))
# 5 ┄       (@_3 = Base.iterate(%1, %9))
# │   %21 = @_3::Union{Nothing, Tuple{Union{ChebyshevSeries{Float64, 1}, TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}}, Int64}}
# │   %22 = (%21 === nothing)::Bool
# │   %23 = Base.not_int(%22)::Bool
# └──       goto #7 if not %23
# 6 ─       goto #2
# 7 ┄ %26 = Main.Chebyshev.throw::Core.Const(throw)
# │   %27 = Main.Chebyshev.DomainError::Core.Const(DomainError)
# │   %28 = (%27)(x)::Core.PartialStruct(DomainError, Any[SVector{1, Float64}, Core.Const("")])
# │         (%26)(%28)
# └──       Core.Const(:(return %29))

# %%
@code_warntype cc(x5)
# Out:
# MethodInstance for (::ChebyshevCluster{Float64, 1, Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, ChebyshevSeries{Float64, 1}}})(::SVector{1, Float64})
#   from (h::ChebyshevCluster{T, N, S} where S<:Tuple{Vararg{AbstractChebyshevSeries{T, N}}})(x::SVector{N, T}) where {T, N} @ Main.Chebyshev ~/repos/WaveGreen2D/notebooks/clenshaw.jl:102
# Static Parameters
#   T = Float64
#   N = 1
# Arguments
#   h::ChebyshevCluster{Float64, 1, Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, ChebyshevSeries{Float64, 1}}}
#   x::SVector{1, Float64}
# Locals
#   i::Int64
# Body::Float64
# 1 ─ %1  = Main.Chebyshev.contains::Core.Const(Main.Chebyshev.contains)
# │         (i = (%1)(h, x))
# │   %3  = Main.Chebyshev.:(==)::Core.Const(==)
# │   %4  = i::Int64
# │   %5  = (%3)(%4, 0)::Bool
# └──       goto #3 if not %5
# 2 ─ %7  = Main.Chebyshev.throw::Core.Const(throw)
# │   %8  = Main.Chebyshev.DomainError::Core.Const(DomainError)
# │   %9  = (%8)(x)::Core.PartialStruct(DomainError, Any[SVector{1, Float64}, Core.Const("")])
# │         (%7)(%9)
# └──       Core.Const(:(goto %12))
# 3 ┄ %12 = Base.getproperty(h, :series)::Tuple{TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}, ChebyshevSeries{Float64, 1}}
# │   %13 = i::Int64
# │   %14 = Base.getindex(%12, %13)::Union{ChebyshevSeries{Float64, 1}, TransformedChebyshevSeries{Float64, 1, typeof(u), typeof(∇u), typeof(Hu)}}
# │   %15 = (%14)(x)::Float64
# └──       return %15

# %%
function fx(x::SVector{2, Float64})
    return exp(x[1]) * cos(x[2])
end

function f(u::SVector{2, Float64})
    x = u[1]*cos(u[2])
    y = u[1]*sin(u[2])
    return exp(x) * cos(y)
end

function ∇f(u)
    x = u[1]*cos(u[2])
    y = u[1]*sin(u[2])
    return SA[exp(x)*cos(y), -exp(x)*sin(y)]
end

function Hf(u)
    x = u[1]*cos(u[2])
    y = u[1]*sin(u[2])
    return SA[ exp(x)*cos(y) -exp(x)*sin(y);
              -exp(x)*sin(y) -exp(x)*cos(y)]
end

function u(x::SVector{2, Float64})
    return SA[sqrt(x[1]^2 + x[2]^2), atan(x[2]/x[1])]
end

function ∇u(x::SVector{2, Float64})
    r² = x[1]^2 + x[2]^2
    r = √r²
    
    ∇u₁ = SA[ x[1]/r , x[2]/r ]
    ∇u₂ = SA[-x[2]/r², x[1]/r²]
    
    return vcat(∇u₁', ∇u₂')
end

function Hu(x::SVector{2, Float64})
    xy = x[1]*x[2]
    x², y² = x.^2
    r² = x² + y²
    r = √r²
    r³ = r²*r
    r⁴ = r³*r

    Hu₁ = [ y²/r³  -xy/r³;
           -xy/r³   x²/r³]
    Hu₂ = [ 2xy/r⁴    (y²-x²)/r⁴;
           (y²-x²)/r⁴ -2xy/r⁴   ]

    hess_u = vcat(reshape(Hu₁, 1, 2, 2), reshape(Hu₂, 1, 2, 2))
    
    return SArray{Tuple{2, 2, 2}, Float64}(hess_u)
end

function u_to_x(u::SVector{2, Float64})
    return SA[u[1]*cos(u[2]), u[1]*sin(u[2])]
end

u1 = SA[0.1, -0.2*π]
u2 = SA[2.0, 0.4*π]

n = (50, 50)

xc = chebpoints(n, u1, u2)
cb = chebinterp(f.(xc), u1, u2)
cs = ChebyshevSeries(cb.coefs, u1, u2)

tcs = TransformedChebyshevSeries(cs, u, ∇u, Hu);

# %%
u3 = SA[0.6, -0.1]
x3 = u_to_x(u3);

# %%
g = tcs(x3)

println(g)
println(f(u3))
println()

tcs(x3) - f(u3)
# Out:
# 1.813407037988697
# 1.813407037988697
# 0.0

# %%
g, ∇g = gradient(tcs, x3)

println(g)
println(f(u3))
println()
println(∇g)
println(∇f(u3))
println()

println(g - f(u3))
println(∇g - ∇f(u3))
# Out:
# 1.813407037988697
# 1.813407037988697
#
# [1.8134070379887002, 0.10875327284161601]
# [1.813407037988697, 0.1087532728416087]
#
# 0.0
# [3.1086244689504383e-15, 7.313594174718219e-15]

# %%
g, ∇g, Hg = hessian(tcs, x3)

println(g)
println(f(u3))
println()
println(∇g)
println(∇f(u3))
println()
println(Hg)
println(Hf(u3))
println()

println(g - f(u3))
println(∇g - ∇f(u3))
println(Hg - Hf(u3))
# Out:
# 1.813407037988697
# 1.813407037988697
#
# [1.8134070379887002, 0.10875327284161601]
# [1.813407037988697, 0.1087532728416087]
#
# [1.8134070379886391 0.1087532728415262; 0.10875327284152608 -1.8134070379891494]
# [1.813407037988697 0.1087532728416087; 0.1087532728416087 -1.813407037988697]
#
# 0.0
# [3.1086244689504383e-15, 7.313594174718219e-15]
# [-5.795364188543317e-14 -8.250344851745695e-14; -8.261447081991946e-14 -4.5230486023228877e-13]
