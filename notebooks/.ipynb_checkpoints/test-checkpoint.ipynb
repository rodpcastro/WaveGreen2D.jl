# %%
using Pkg
Pkg.activate("../test")
Pkg.instantiate()
Pkg.status()
# Out:
#   Activating project at `~/repos/WaveGreen2D/test`
# Status `~/repos/WaveGreen2D/test/Project.toml`
#   [4c88cf16] Aqua v0.8.14
#   [c3a54625] JET v0.11.3
#   [8dfed614] Test v1.11.0

# %%
# Running it twice throws an error.
# using TestEnv
# TestEnv.activate()

# using Pkg
# Pkg.status()
# Out:
# Status `/tmp/jl_x3dqrd/Project.toml`
#   [4c88cf16] Aqua v0.8.14
#   [c3a54625] JET v0.11.3
#   [afc8eec6] WaveGreen2D v0.0.1 `~/repos/WaveGreen2D`
#   [8dfed614] Test v1.11.0
