# %%
import Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#   Activating project at `~/repos/WaveGreen2D/notebooks`
# Precompiling packages...
#    2830.0 ms  ✓ WaveGreen2D
#   1 dependency successfully precompiled in 4 seconds. 304 already precompiled.

# %%
using WaveGreen2D: setwave!, wave

# %%
setwave!(depth=10.0, frequency=0.8)
# Out:
# [ Info: Wave parameters h = 10.0 m, ω = 0.8 rad/s, g = 9.81 m/s²

# %% [markdown]
# ![image.png](attachment:1068ce5f-a8cc-43d5-bd01-4bf57fd914e2.png)

# %% [markdown]
# ![image.png](attachment:0771d43f-a4e1-4c6b-841d-281e1bd9e05d.png)

# %%
function Gᴿ()
    
end
