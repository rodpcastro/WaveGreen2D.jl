# %%
import Pkg
Pkg.activate(".")
# Out:
#   Activating project at `~/repos/WaveGreen2D/notebooks`

# %%
using WaveGreen2D: wave, setwave!

# %%
setwave!(depth=100.0, frequency=2π/10)
# Out:
# Wave parameters: h = 100.0 m, ω = 0.63 rad/s, k₀ = 0.04 m, g = 9.81 m/s²

# %%
@code_warntype setwave!(depth=100.0, frequency=2π/10)
# Out:
# MethodInstance for Core.kwcall(::@NamedTuple{depth::Float64, frequency::Float64}, ::typeof(setwave!))
#   from kwcall(::NamedTuple, ::typeof(setwave!)) @ WaveGreen2D ~/repos/WaveGreen2D/src/wave_params.jl:39
# Arguments
#   _::Core.Const(Core.kwcall)
#   @_2::@NamedTuple{depth::Float64, frequency::Float64}
#   @_3::Core.Const(WaveGreen2D.setwave!)
# Locals
#   @_4::Union{Nothing, Float64}
#   depth::Float64
#   frequency::Float64
#   wavenumber::Nothing
#   gravity::Float64
# Body::WaveGreen2D.WaveParameters
# 1 ──       Core.NewvarNode(:(@_4))
# │    %2  = Core.isdefined(@_2, :depth)::Core.Const(true)
# └───       goto #6 if not %2
# 2 ── %4  = Core.getfield(@_2, :depth)::Float64
# │    %5  = WaveGreen2D.Real::Core.Const(Real)
# │    %6  = (%4 isa %5)::Core.Const(true)
# └───       goto #4 if not %6
# 3 ──       goto #5
# 4 ──       Core.Const(:(WaveGreen2D.Real))
# │          Core.Const(:(%new(Core.TypeError, Symbol("keyword argument"), :depth, %9, %4)))
# ...
